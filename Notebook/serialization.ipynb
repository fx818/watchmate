# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Two type of serialization
# * serializers.Serialization
# * serializers.ModelSerialization
#
# ![image.png](attachment:image.png)
