# %% [markdown]
# ## ViewSets and Routers
# * When you have to use both list as well as detail of the product you can use Viewsets and routers

# %% [markdown]
# ## Model Viewsets
# * Just use this
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
