# %% [markdown]
# ### String related field
# * Gives whatever we define in the _ _ str _ _ function in our model class
#
# * ![image-2.png](attachment:image-2.png)
#
# ### Primary key related field
# * Here you will get the primary key in the api object
#
# * ![image.png](attachment:image.png)
#
# ## Hyperlink related field (Important field)
# * If you want the link that you have stored the object, you can use
# * ![image-3.png](attachment:image-3.png)
# * Pass the name that you have defined in the urls.py file
# * You will also need to add the context in the views.py file of which you are using the urls
#
# * ![image-4.png](attachment:image-4.png)
#
# ### Slug related field
#
# ### Hyperlinked identity field
